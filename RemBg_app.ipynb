# %% [markdown]
# <a href="https://colab.research.google.com/github/anees028/RemBg_python_app/blob/main/RemBg_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rembg -q
# !pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 108.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.3 MB/s eta 0:00:00
# ...

# %%
from rembg import remove
from PIL import Image

# %%
#remove?

# %% [markdown]
# # **Usage as a library**
# ## *Single Image*

# %%
from PIL import Image

img = Image.open('/content/input-images/car-input.jpg')
img.show()

# %%
from IPython.display import Image, display

display(Image(filename='car-input.jpg'))

# %%
from PIL import Image
input_path = 'car-input.jpg'
output_path = 'car-output.png'

input = Image.open(input_path)
output = remove(input)
output.save(output_path)
# Out:
# ...
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 283GB/s]

# %% [markdown]
# ### **Output** for converted image.

# %%
from IPython.display import Image, display

display(Image(filename='car-output.png'))
